# %% [markdown]
# # The spread of true and false news online
#
# Soroush Vosoughi, Deb Roy, Sinan Aral,*
#
# Science  09 Mar 2018: Vol. 359, Issue 6380, pp. 1146-1151
# DOI: 10.1126/science.aap9559 https://science.sciencemag.org/content/359/6380/1146.full

# %% [markdown]
# - 作业1. False news the spread of true and false news online. The data and code is freely available at https://goo.gl/forms/AKIlZujpexhN7fY33.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 任务1. 绘制Figrue 1A
# ![image.png](attachment:image.png)

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
alist = [['a', 'b'], ['a', 'c'],['b', 'd'], ['c', 'e'], ['c', 'f'], ['d', 'g'], ['c', 'h']]
g = nx.Graph()
for i,j in alist:
    g.add_edge(i,j)

# %%
# set the position of nodes
pos={'a': np.array([ 0.2 , 0.5]),
     'b': np.array([ 0.3,  0.55]),
     'c': np.array([ 0.5,  0.45]),
     'd': np.array([ 0.6,  0.55]),
     'e': np.array([ 0.8,  0.5]),
     'f': np.array([ 0.9,  0.4]),
     'g': np.array([ 1.0,  0.55 ]),
     'h': np.array([ 1.2,  0.45])}
plt.figure(figsize = [8, 2])
nx.draw(g, with_labels = True, pos = pos)

# %%
def calc_depth(G,G_root):
    depth=nx.eccentricity(G,v=G_root)
    return depth

# %%
# 计算g网络的深度
calc_depth(g, 'a')
# Out:
# 3

# %% [markdown]
# ## 任务2. 申请Data
# https://goo.gl/forms/AKIlZujpexhN7fY33. The entire data set is also available, from the same link, upon signing an access agreement stating that
# - (i) you shall only use the data set for the purpose of validating the results of the MIT study and for no other purpose;
# - (ii) you shall not attempt to identify, reidentify, or otherwise deanonymize the data set; and
# - (iii) you shall not further share, distribute, publish, or otherwise disseminate the data set.
#
# Those who wish to use the data for any other purposes can contact and make a separate agreement with Twitter.
#
# If you have any questions about the data or the code (or the libraries) please contact me at soroush@mit.edu
#
#
# ### emotions.csv
# Has all the emotion data for **Figures 4d and 4f**. Each row contains an tweet_id and the emotional breakdown of the replies.
#
# ### topics.csv
# Has all the topic data for calculating novelty for Figures 4c and 4e. Each row contains a tweet_id, the rumor_id, the rumor veracity and tweet and background topics.
# The tweet and background topics are 200 dimensional vectors.
#
# ### raw_data.csv
# Has the ananomized raw_data for every single tweet and retweet. It includes infroamtion about user and the propagation path. This data can be used to recreate all cascades.
#
# The parent_id points to the parent of a node. If parent_id is -1, the node is the root node.
# Creating and processing the cascades is very time consuming, therefore we have also included the already processed file (see below):
#
# ### regression_data.txt
# Contains data for the regression model in Figure 4b
#
# ### meta_data.txt
# Is the processed version of raw_data.csv. **All findings in the paper can be replicated using this file, in conjunction with topics.csv, emotions.csv and regression_data.csv**.
#
# Note that this is not a csv file, this is a text files that is evaluated by python and turned into python objects.
#
# Please note that due to our agreement with Twitter, we have removed all identified bot accounts/activity from the dataset provided

# %% [markdown]
# ## 任务3. 读取Data

# %%
cd '/Users/xilin/Desktop/TechX 作业/D6/FalseNews_Code_Data/data/'
# Out:
# /Users/xilin/Desktop/TechX 作业/D6/FalseNews_Code_Data/data

# %%
ls
# Out:
# emotions_anon.csv         raw_data_anon.csv         topics_anon.csv
# metadata_anon.txt         regression_data_anon.txt

# %%
raw_data_file='raw_data_anon.csv'
regression_file='regression_data_anon.txt'
metadata_file='metadata_anon.txt'
emotions_file='emotions_anon.csv'
topics_file='topics_anon.csv'

# %%
# "Reading metadata..."
with open(metadata_file,'r') as f:
    lines=f.readlines()

cascade_id2metadata={}
for line in lines:
    line=line.replace('\n','').replace('datetime.datetime', '')
    item=eval(line)
    cascade_id2metadata[item[0]]=item[1] #将lines内容加入字典。第0项是编号，第1项是包含所有数据的字典

# %%
cascade_id2metadata
# Out:
# {1: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_0',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [236],
#   'engagement_list': [7.09240543598],
#   'num_followers_list': [164],
#   'accountage_list': [1326],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 0,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2013, 8, 22, 21, 9, 8),
#   'size': 1},
#  10: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_1',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [1999],
#   'engagement_list': [8.39449955042],
#   'num_followers_list': [870],
#   'accountage_list': [988],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 1,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 23, 14, 10, 17),
#   'size': 1},
#  100: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_2',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [1982],
#   'engagement_list': [6.72967899601],
#   'num_followers_list': [452],
#   'accountage_list': [1190],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 2,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2015, 5, 9, 16, 49),
#   'size': 1},
#  1000: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_3',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [55],
#   'engagement_list': [0.186417552951],
#   'num_followers_list': [5],
#   'accountage_list': [682],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 3,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2013, 10, 15, 20, 30, 53),
#   'size': 1},
#  10000: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_4',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [129],
#   'engagement_list': [1.42591453505],
#   'num_followers_list': [95],
#   'accountage_list': [1496],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 4,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 14, 14, 28, 16),
#   'size': 1},
#  100000: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [353],
#   'engagement_list': [2.29967384516],
#   'num_followers_list': [175],
#   'accountage_list': [1777],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 5,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 5, 18, 10, 4, 28),
#   'size': 1},
#  100001: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [993],
#   'engagement_list': [15.4136590211],
#   'num_followers_list': [18044],
#   'accountage_list': [493],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 6,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 18, 16, 17, 51),
#   'size': 1},
#  100002: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [86],
#   'engagement_list': [0.0574847651823],
#   'num_followers_list': [33],
#   'accountage_list': [27],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 7,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 5, 13, 9, 18, 40),
#   'size': 1},
#  100003: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1230],
#   'engagement_list': [11.1525556489],
#   'num_followers_list': [931],
#   'accountage_list': [1805],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 8,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 17, 16, 59, 59),
#   'size': 1},
#  100004: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_7',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [994],
#   'engagement_list': [27.4630583307],
#   'num_followers_list': [1442],
#   'accountage_list': [1912],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 9,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 2, 14, 11, 9, 24),
#   'size': 1},
#  100005: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [319],
#   'engagement_list': [5.63592901036],
#   'num_followers_list': [188],
#   'accountage_list': [1606],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 10,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 4, 28, 2, 39, 37),
#   'size': 1},
#  100006: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_8',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [4750],
#   'engagement_list': [61.1385270112],
#   'num_followers_list': [5637],
#   'accountage_list': [595],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 11,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2015, 9, 10, 12, 24, 9),
#   'size': 1},
#  100007: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [955],
#   'engagement_list': [1.32479578495],
#   'num_followers_list': [946],
#   'accountage_list': [2498],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 12,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 9, 40, 50),
#   'size': 1},
#  100008: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [260],
#   'engagement_list': [2.42610835192],
#   'num_followers_list': [173],
#   'accountage_list': [401],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 13,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 3, 5, 22, 1, 41),
#   'size': 1},
#  100009: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [70730],
#   'engagement_list': [62.8685026002],
#   'num_followers_list': [70024],
#   'accountage_list': [2569],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 14,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 13, 11, 1),
#   'size': 1},
#  10001: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_4',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [109],
#   'engagement_list': [1.08044903129],
#   'num_followers_list': [177],
#   'accountage_list': [2747],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 15,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 9, 18, 19, 27, 15),
#   'size': 1},
#  100010: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [585],
#   'engagement_list': [3.48181879391],
#   'num_followers_list': [298],
#   'accountage_list': [1504],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 16,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 11, 17, 1, 46, 55),
#   'size': 1},
#  100011: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [243],
#   'engagement_list': [0.673231509229],
#   'num_followers_list': [120],
#   'accountage_list': [2884],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 17,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 14, 58, 57),
#   'size': 1},
#  100012: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [989],
#   'engagement_list': [27.7870577771],
#   'num_followers_list': [554],
#   'accountage_list': [362],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 18,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 17, 42, 28),
#   'size': 1},
#  100013: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1101],
#   'engagement_list': [2.75872683591],
#   'num_followers_list': [920],
#   'accountage_list': [2515],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 19,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 28, 20, 51, 19),
#   'size': 1},
#  100014: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [433],
#   'engagement_list': [12.5582598328],
#   'num_followers_list': [408],
#   'accountage_list': [292],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 20,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 24, 9, 53, 23),
#   'size': 1},
#  100015: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [123],
#   'engagement_list': [0.0947255102359],
#   'num_followers_list': [19],
#   'accountage_list': [1826],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 21,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 4, 25, 13, 48, 36),
#   'size': 1},
#  100016: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [60],
#   'engagement_list': [0.329804076195],
#   'num_followers_list': [16],
#   'accountage_list': [2223],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 22,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 0, 2, 44),
#   'size': 1},
#  100017: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1099],
#   'engagement_list': [6.51660034947],
#   'num_followers_list': [377],
#   'accountage_list': [1617],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 23,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 27, 3, 12, 5),
#   'size': 1},
#  100018: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1310],
#   'engagement_list': [2.80113303111],
#   'num_followers_list': [809],
#   'accountage_list': [2326],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 24,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 2, 21, 3),
#   'size': 1},
#  100019: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [567],
#   'engagement_list': [1.52663534905],
#   'num_followers_list': [258],
#   'accountage_list': [2001],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 25,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 1, 50, 14),
#   'size': 1},
#  10002: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_11',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [445],
#   'engagement_list': [13.7498511415],
#   'num_followers_list': [310],
#   'accountage_list': [1653],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 26,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 19, 19, 46, 21),
#   'size': 1},
#  100020: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [661],
#   'engagement_list': [11.0773897679],
#   'num_followers_list': [899],
#   'accountage_list': [1487],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 27,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 23, 21, 9, 28),
#   'size': 1},
#  100021: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [255],
#   'engagement_list': [20.4695852675],
#   'num_followers_list': [306],
#   'accountage_list': [487],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 28,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 16, 17, 49, 11),
#   'size': 1},
#  100022: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [243],
#   'engagement_list': [7.15636546615],
#   'num_followers_list': [416],
#   'accountage_list': [1623],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 29,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 3, 24, 9, 50, 42),
#   'size': 1},
#  100023: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [45],
#   'engagement_list': [0.352732433354],
#   'num_followers_list': [77],
#   'accountage_list': [124],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 30,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 16, 19, 39, 23),
#   'size': 1},
#  100024: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_12',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [734],
#   'engagement_list': [19.0466298019],
#   'num_followers_list': [892],
#   'accountage_list': [536],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 31,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2016, 2, 3, 2, 30, 21),
#   'size': 1},
#  100025: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [387],
#   'engagement_list': [2.26331348882],
#   'num_followers_list': [252],
#   'accountage_list': [767],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 32,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 23, 13, 35, 24),
#   'size': 1},
#  100026: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_13',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [98],
#   'engagement_list': [0.636608202696],
#   'num_followers_list': [42],
#   'accountage_list': [795],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 33,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 20, 3, 2, 40),
#   'size': 1},
#  100027: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [98],
#   'engagement_list': [3.26032603819],
#   'num_followers_list': [17],
#   'accountage_list': [158],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 34,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 9, 30, 3, 16, 38),
#   'size': 1},
#  100028: {'virality': None,
#   'verified_list': [True],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [592],
#   'engagement_list': [10.8657387732],
#   'num_followers_list': [4330],
#   'accountage_list': [1462],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 35,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 18, 16, 13, 58),
#   'size': 1},
#  100029: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1775],
#   'engagement_list': [6.15052663851],
#   'num_followers_list': [169],
#   'accountage_list': [1019],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 36,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 4, 17, 3, 11, 32),
#   'size': 1},
#  10003: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_4',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [42],
#   'engagement_list': [8.79541671323],
#   'num_followers_list': [1],
#   'accountage_list': [53],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 37,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 8, 25, 14, 46, 16),
#   'size': 1},
#  100030: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1182],
#   'engagement_list': [54.5116962568],
#   'num_followers_list': [1284],
#   'accountage_list': [616],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 38,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 3, 19, 19, 48, 13),
#   'size': 1},
#  100031: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [933],
#   'engagement_list': [2.0258744125],
#   'num_followers_list': [538],
#   'accountage_list': [1648],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 39,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 12, 55, 55),
#   'size': 1},
#  100032: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1902],
#   'engagement_list': [18.6584493332],
#   'num_followers_list': [1194],
#   'accountage_list': [1484],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 40,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 20, 1, 21),
#   'size': 1},
#  100033: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [100],
#   'engagement_list': [2.10324279605],
#   'num_followers_list': [54],
#   'accountage_list': [2453],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 41,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 2, 25, 0, 40, 50),
#   'size': 1},
#  100034: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [606],
#   'engagement_list': [0.121513710074],
#   'num_followers_list': [153],
#   'accountage_list': [1542],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 42,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 30, 9, 13, 28),
#   'size': 1},
#  100035: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_12',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [83],
#   'engagement_list': [0.273924595143],
#   'num_followers_list': [91],
#   'accountage_list': [2294],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 43,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2016, 2, 2, 10, 28, 29),
#   'size': 1},
#  100036: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [956],
#   'engagement_list': [8.61390128326],
#   'num_followers_list': [3288],
#   'accountage_list': [1783],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 44,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 24, 12, 10, 26),
#   'size': 1},
#  100037: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [372],
#   'engagement_list': [40.3027448615],
#   'num_followers_list': [885],
#   'accountage_list': [2425],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 45,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 3, 30, 20, 4, 51),
#   'size': 1},
#  100038: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_12',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [37],
#   'engagement_list': [0.299264006279],
#   'num_followers_list': [49],
#   'accountage_list': [2312],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 46,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2016, 2, 5, 8, 36, 26),
#   'size': 1},
#  100039: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_13',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [2291],
#   'engagement_list': [252.182828787],
#   'num_followers_list': [1243],
#   'accountage_list': [890],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 47,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 20, 0, 21, 29),
#   'size': 1},
#  10004: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_14',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [975],
#   'engagement_list': [4.54735584598],
#   'num_followers_list': [194],
#   'accountage_list': [1146],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 48,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 13, 6, 19, 52),
#   'size': 1},
#  100040: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [113],
#   'engagement_list': [0.25859299863],
#   'num_followers_list': [35],
#   'accountage_list': [1003],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 49,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 23, 19, 17, 52),
#   'size': 1},
#  100041: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [109],
#   'engagement_list': [3.24125067636],
#   'num_followers_list': [55],
#   'accountage_list': [437],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 50,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 28, 22, 58, 46),
#   'size': 1},
#  100042: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [595],
#   'engagement_list': [8.9047074466],
#   'num_followers_list': [583],
#   'accountage_list': [1271],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 51,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 28, 23, 40, 29),
#   'size': 1},
#  100043: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [46],
#   'engagement_list': [0.166520671102],
#   'num_followers_list': [17],
#   'accountage_list': [2106],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 52,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 28, 22, 4, 7),
#   'size': 1},
#  100044: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [88],
#   'engagement_list': [6.47212182539],
#   'num_followers_list': [3],
#   'accountage_list': [26],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 53,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 7, 26, 13, 56, 43),
#   'size': 1},
#  100045: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [671],
#   'engagement_list': [3.93205860679],
#   'num_followers_list': [358],
#   'accountage_list': [206],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 54,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 23, 19, 24, 16),
#   'size': 1},
#  100046: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_13',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [6271],
#   'engagement_list': [63.0523364229],
#   'num_followers_list': [6253],
#   'accountage_list': [2867],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 55,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 19, 19, 42, 11),
#   'size': 1},
#  100047: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1026],
#   'engagement_list': [2.40803358721],
#   'num_followers_list': [804],
#   'accountage_list': [2737],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 56,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 28, 23, 49, 49),
#   'size': 1},
#  100048: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_15',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [265],
#   'engagement_list': [0.00277421511746],
#   'num_followers_list': [44],
#   'accountage_list': [1171],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 57,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 20, 8, 2, 25),
#   'size': 1},
#  100049: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [2275],
#   'engagement_list': [6.4102283366],
#   'num_followers_list': [1446],
#   'accountage_list': [2596],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 58,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 28, 19, 36, 14),
#   'size': 1},
#  10005: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_16',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [4263],
#   'engagement_list': [6.80387219181],
#   'num_followers_list': [4498],
#   'accountage_list': [2816],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 59,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 1, 17, 3, 6, 10),
#   'size': 1},
#  100050: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [715],
#   'engagement_list': [23.5433370425],
#   'num_followers_list': [216],
#   'accountage_list': [1537],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 60,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 26, 10, 32, 34),
#   'size': 1},
#  100051: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_12',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [270],
#   'engagement_list': [66.7578763662],
#   'num_followers_list': [445],
#   'accountage_list': [1304],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 61,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2016, 2, 3, 4, 9, 8),
#   'size': 1},
#  100052: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_12',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1447],
#   'engagement_list': [9.86272580952],
#   'num_followers_list': [620],
#   'accountage_list': [1282],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 62,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2016, 2, 3, 14, 20, 27),
#   'size': 1},
#  100053: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [877],
#   'engagement_list': [3.88005506894],
#   'num_followers_list': [468],
#   'accountage_list': [2610],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 63,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 18, 41, 31),
#   'size': 1},
#  100054: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1285],
#   'engagement_list': [16.6190948976],
#   'num_followers_list': [852],
#   'accountage_list': [1086],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 64,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 3, 4, 43),
#   'size': 1},
#  100055: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [183],
#   'engagement_list': [43.3525340757],
#   'num_followers_list': [846],
#   'accountage_list': [1590],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 65,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 11, 8, 3),
#   'size': 1},
#  100056: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_7',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [352],
#   'engagement_list': [20.6822884705],
#   'num_followers_list': [286],
#   'accountage_list': [745],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 66,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 3, 2, 4, 46, 46),
#   'size': 1},
#  100057: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [2404],
#   'engagement_list': [29.0774341063],
#   'num_followers_list': [1734],
#   'accountage_list': [2635],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 67,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 28, 23, 40, 5),
#   'size': 1},
#  100058: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [162],
#   'engagement_list': [3.96468785844],
#   'num_followers_list': [102],
#   'accountage_list': [92],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 68,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 14, 19, 29),
#   'size': 1},
#  100059: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [2077],
#   'engagement_list': [10.541205591],
#   'num_followers_list': [1059],
#   'accountage_list': [1312],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 69,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 30, 22, 45, 25),
#   'size': 1},
#  10006: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_17',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [182],
#   'engagement_list': [1.48834438857],
#   'num_followers_list': [69],
#   'accountage_list': [864],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 70,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 2, 1, 7, 30, 15),
#   'size': 1},
#  100060: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [256],
#   'engagement_list': [1.51167771672],
#   'num_followers_list': [227],
#   'accountage_list': [838],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 71,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 24, 2, 25, 26),
#   'size': 1},
#  100061: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [154],
#   'engagement_list': [1.36401885376],
#   'num_followers_list': [31],
#   'accountage_list': [888],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 72,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 18, 58, 16),
#   'size': 1},
#  100062: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [437],
#   'engagement_list': [5.89015485306],
#   'num_followers_list': [860],
#   'accountage_list': [530],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 73,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 25, 10, 32, 18),
#   'size': 1},
#  100063: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [49],
#   'engagement_list': [7.07609445889],
#   'num_followers_list': [89],
#   'accountage_list': [1093],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 74,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 4, 1, 4, 29, 5),
#   'size': 1},
#  100064: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [721],
#   'engagement_list': [3.32576686828],
#   'num_followers_list': [961],
#   'accountage_list': [887],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 75,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 25, 23, 19, 59),
#   'size': 1},
#  100065: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [342],
#   'engagement_list': [1.8073211089],
#   'num_followers_list': [122],
#   'accountage_list': [1020],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 76,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 8, 16, 37),
#   'size': 1},
#  100066: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [131],
#   'engagement_list': [0.257954126042],
#   'num_followers_list': [18],
#   'accountage_list': [238],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 77,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 24, 17, 25, 43),
#   'size': 1},
#  100067: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_13',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [402],
#   'engagement_list': [10.6306937276],
#   'num_followers_list': [426],
#   'accountage_list': [729],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 78,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 19, 19, 13, 57),
#   'size': 1},
#  100068: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_18',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1969],
#   'engagement_list': [4.69262553264],
#   'num_followers_list': [1893],
#   'accountage_list': [473],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 79,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2011, 11, 20, 21, 25, 42),
#   'size': 1},
#  100069: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [259],
#   'engagement_list': [6.76566644922],
#   'num_followers_list': [266],
#   'accountage_list': [596],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 80,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 19, 23, 33, 10),
#   'size': 1},
#  10007: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_19',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [223],
#   'engagement_list': [156.493752282],
#   'num_followers_list': [486],
#   'accountage_list': [623],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 81,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 6, 13, 4, 58, 14),
#   'size': 1},
#  100070: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [188],
#   'engagement_list': [0.423106260639],
#   'num_followers_list': [124],
#   'accountage_list': [1536],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 82,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 24, 15, 4, 44),
#   'size': 1},
#  100071: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_12',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [691],
#   'engagement_list': [232.677684944],
#   'num_followers_list': [2463],
#   'accountage_list': [511],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 83,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2016, 2, 2, 19, 2, 34),
#   'size': 1},
#  100072: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1984],
#   'engagement_list': [7.74160901408],
#   'num_followers_list': [783],
#   'accountage_list': [2605],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 84,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 9, 16, 35),
#   'size': 1},
#  100073: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1110],
#   'engagement_list': [0.808790007028],
#   'num_followers_list': [239],
#   'accountage_list': [1481],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 85,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 4, 26, 11, 9, 44),
#   'size': 1},
#  100074: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [890],
#   'engagement_list': [2.38552179862],
#   'num_followers_list': [621],
#   'accountage_list': [1423],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 86,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 24, 11, 59, 57),
#   'size': 1},
#  100075: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [193],
#   'engagement_list': [3.43605460173],
#   'num_followers_list': [173],
#   'accountage_list': [1320],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 87,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 5, 51, 21),
#   'size': 1},
#  100076: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [74],
#   'engagement_list': [4.30892949619],
#   'num_followers_list': [41],
#   'accountage_list': [190],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 88,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 12, 29, 31),
#   'size': 1},
#  100077: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [7377],
#   'engagement_list': [7.25588437195],
#   'num_followers_list': [6022],
#   'accountage_list': [696],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 89,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 25, 14, 52, 58),
#   'size': 1},
#  100078: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [11],
#   'engagement_list': [0.00396080711645],
#   'num_followers_list': [1],
#   'accountage_list': [2246],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 90,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 1, 10, 6),
#   'size': 1},
#  100079: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [225],
#   'engagement_list': [1.02681006236],
#   'num_followers_list': [237],
#   'accountage_list': [2434],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 91,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 4, 1, 22, 20, 29),
#   'size': 1},
#  10008: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_14',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [511],
#   'engagement_list': [10.8936384497],
#   'num_followers_list': [565],
#   'accountage_list': [595],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 92,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 13, 1, 41, 5),
#   'size': 1},
#  100080: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_12',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [139],
#   'engagement_list': [9.33432174728],
#   'num_followers_list': [128],
#   'accountage_list': [179],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 93,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2016, 2, 3, 19, 0, 40),
#   'size': 1},
#  100081: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [268],
#   'engagement_list': [3.0846476307],
#   'num_followers_list': [4405],
#   'accountage_list': [683],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 94,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 5, 4, 20, 59, 44),
#   'size': 1},
#  100082: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [580],
#   'engagement_list': [0.927868109963],
#   'num_followers_list': [188],
#   'accountage_list': [2055],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 95,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 28, 23, 12, 26),
#   'size': 1},
#  100083: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [293],
#   'engagement_list': [37.7951202166],
#   'num_followers_list': [5961],
#   'accountage_list': [2792],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 96,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 13, 18, 57),
#   'size': 1},
#  100084: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [310],
#   'engagement_list': [1.82683849867],
#   'num_followers_list': [190],
#   'accountage_list': [2557],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 97,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 4, 49, 49),
#   'size': 1},
#  100085: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [393],
#   'engagement_list': [0.896249959744],
#   'num_followers_list': [376],
#   'accountage_list': [1532],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 98,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 17, 18, 10, 56),
# ...
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1919],
#   'engagement_list': [0.458525457782],
#   'num_followers_list': [460],
#   'accountage_list': [3257],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 967,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 4, 4, 54),
#   'size': 1},
#  100869: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [414],
#   'engagement_list': [2.70572630857],
#   'num_followers_list': [155],
#   'accountage_list': [974],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 968,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 8, 1, 8, 13, 23),
#   'size': 1},
#  10087: {'virality': None,
#   'verified_list': [True],
#   'rumor_id': 'r_42',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [1323],
#   'engagement_list': [5.12582278435],
#   'num_followers_list': [4267],
#   'accountage_list': [2684],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 969,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 7, 29, 16, 2, 21),
#   'size': 1},
#  100870: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [974],
#   'engagement_list': [10.9764583256],
#   'num_followers_list': [1352],
#   'accountage_list': [175],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 970,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 5, 6, 13, 0, 14),
#   'size': 1},
#  100871: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [263],
#   'engagement_list': [6.49453987145],
#   'num_followers_list': [204],
#   'accountage_list': [779],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 971,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 26, 10, 29, 58),
#   'size': 1},
#  100872: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [529],
#   'engagement_list': [1.26209279558],
#   'num_followers_list': [282],
#   'accountage_list': [1855],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 972,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 4, 14, 28),
#   'size': 1},
#  100873: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [138],
#   'engagement_list': [5.7773224176],
#   'num_followers_list': [105],
#   'accountage_list': [24],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 973,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 27, 14, 58, 31),
#   'size': 1},
#  100874: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1105],
#   'engagement_list': [2.65613835258],
#   'num_followers_list': [1563],
#   'accountage_list': [2409],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 974,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 14, 32, 26),
#   'size': 1},
#  100875: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1004],
#   'engagement_list': [0.897321423692],
#   'num_followers_list': [137],
#   'accountage_list': [1876],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 975,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 12, 19, 10),
#   'size': 1},
#  100876: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [2302],
#   'engagement_list': [2.01025521701],
#   'num_followers_list': [8545],
#   'accountage_list': [1448],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 976,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 17, 15, 12, 20),
#   'size': 1},
#  100877: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [2102],
#   'engagement_list': [1.6073944785],
#   'num_followers_list': [585],
#   'accountage_list': [282],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 977,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 5, 16, 20, 36, 12),
#   'size': 1},
#  100878: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_7',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1402],
#   'engagement_list': [26.1729670045],
#   'num_followers_list': [1551],
#   'accountage_list': [1302],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 978,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 2, 25, 7, 4, 26),
#   'size': 1},
#  100879: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [392],
#   'engagement_list': [1.57507084156],
#   'num_followers_list': [38],
#   'accountage_list': [1783],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 979,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 30, 7, 6, 30),
#   'size': 1},
#  10088: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_29',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [7037],
#   'engagement_list': [106.549227939],
#   'num_followers_list': [7322],
#   'accountage_list': [33],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 980,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 7, 30, 12, 30, 14),
#   'size': 1},
#  100880: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_6',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [255],
#   'engagement_list': [20.4695852675],
#   'num_followers_list': [306],
#   'accountage_list': [487],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 981,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 16, 17, 52, 39),
#   'size': 1},
#  100881: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_7',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [736],
#   'engagement_list': [2.58226978141],
#   'num_followers_list': [225],
#   'accountage_list': [1476],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 982,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 2, 14, 15, 9, 45),
#   'size': 1},
#  100882: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [504],
#   'engagement_list': [3.89509016224],
#   'num_followers_list': [213],
#   'accountage_list': [948],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 983,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 30, 16, 25, 22),
#   'size': 1},
#  100883: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [887],
#   'engagement_list': [5.47604562773],
#   'num_followers_list': [794],
#   'accountage_list': [2839],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 984,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 28, 22, 53, 2),
#   'size': 1},
#  100884: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [344],
#   'engagement_list': [70.2524815854],
#   'num_followers_list': [258],
#   'accountage_list': [143],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 985,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 30, 11, 27, 34),
#   'size': 1},
#  100885: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_7',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [628],
#   'engagement_list': [1.50301188179],
#   'num_followers_list': [637],
#   'accountage_list': [200],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 986,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 2, 15, 19, 19, 17),
#   'size': 1},
#  100886: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1216],
#   'engagement_list': [10.0229067027],
#   'num_followers_list': [920],
#   'accountage_list': [1361],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 987,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 4, 26, 0, 50, 17),
#   'size': 1},
#  100887: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_7',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [19],
#   'engagement_list': [10.1276537865],
#   'num_followers_list': [369],
#   'accountage_list': [307],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 988,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 2, 18, 12, 0),
#   'size': 1},
#  100888: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [346],
#   'engagement_list': [3.74588414131],
#   'num_followers_list': [436],
#   'accountage_list': [3297],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 989,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 4, 3, 19, 46, 45),
#   'size': 1},
#  100889: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_13',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [476],
#   'engagement_list': [2.59614307953],
#   'num_followers_list': [2504],
#   'accountage_list': [1286],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 990,
#   'rumor_category': 'War/Terrorism/Shootings',
#   'max_breadth': 1,
#   'start_date': (2013, 4, 19, 17, 14, 16),
#   'size': 1},
#  10089: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_17',
#   'depth2time': {},
#   'veracity': 'FALSE',
#   'num_followees_list': [1965],
#   'engagement_list': [7.64938213428],
#   'num_followers_list': [1502],
#   'accountage_list': [1404],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 991,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 1, 31, 21, 28, 17),
#   'size': 1},
#  100890: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [610],
#   'engagement_list': [17.645995216],
#   'num_followers_list': [775],
#   'accountage_list': [1493],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 992,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 3, 25, 12, 13, 26),
#   'size': 1},
#  100891: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [2624],
#   'engagement_list': [6.86523304547],
#   'num_followers_list': [2255],
#   'accountage_list': [2859],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 993,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 12, 30, 49),
#   'size': 1},
#  100892: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [457],
#   'engagement_list': [5.87876231227],
#   'num_followers_list': [273],
#   'accountage_list': [1080],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 994,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 24, 17, 30, 46),
#   'size': 1},
#  100893: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [234],
#   'engagement_list': [8.98254503102],
#   'num_followers_list': [687],
#   'accountage_list': [2666],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 995,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 28, 22, 0, 52),
#   'size': 1},
#  100894: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_5',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [563],
#   'engagement_list': [9.62285218615],
#   'num_followers_list': [537],
#   'accountage_list': [993],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 996,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 6, 13, 10, 48, 6),
#   'size': 1},
#  100895: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [312],
#   'engagement_list': [3.21981649717],
#   'num_followers_list': [347],
#   'accountage_list': [1582],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 997,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 27, 16, 41, 5),
#   'size': 1},
#  100896: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_9',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [2004],
#   'engagement_list': [11.4167686334],
#   'num_followers_list': [328],
#   'accountage_list': [1527],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 998,
#   'rumor_category': 'Politics',
#   'max_breadth': 1,
#   'start_date': (2016, 3, 29, 17, 47, 12),
#   'size': 1},
#  100897: {'virality': None,
#   'verified_list': [False],
#   'rumor_id': 'r_10',
#   'depth2time': {},
#   'veracity': 'TRUE',
#   'num_followees_list': [1055],
#   'engagement_list': [1.48860963535],
#   'num_followers_list': [860],
#   'accountage_list': [1087],
#   'depth2uu': {},
#   'uu2time': {1: 0.0},
#   'depth': 0,
#   'unique_users': 1,
#   'depth2breadth': {},
#   'root_tid': 999,
#   'rumor_category': 'Viral Photos/Stories/Urban Legends',
#   'max_breadth': 1,
#   'start_date': (2014, 1, 24, 19, 47, 31),
#   'size': 1},
#  ...}

# %%
from collections import defaultdict
veracity2number_of_cascades=defaultdict(int)
unique_rumors=set([])#不重复元素集
for cascade,metadata in cascade_id2metadata.items():
    veracity=metadata['veracity'] 
    rid=metadata['rumor_id']
    unique_rumors.add(rid)
    veracity2number_of_cascades[veracity]+=1
# change this line below
print("Number of unique rumors:", len(unique_rumors))
# Out:
# Number of unique rumors: 2448

# %%
# change this line below
print ("Total number of cascades:", sum(veracity2number_of_cascades.values()) )#.values变数字
# Out:
# Total number of cascades: 126301

# %%
veracity2number_of_cascades.items()
# Out:
# dict_items([('FALSE', 82605), ('TRUE', 24409), ('MIXED', 19287)])

# %% [markdown]
# ## Figrue 1B

# %%
#percentage of rumours -- Number of cascades
#设置图参数
veracity2color={"TRUE":'green',
        "FALSE":'red',
        'MIXED':'orange'}
category2linestyle={'Politics':'-',
        'Other':'--'}

import sys
epsilon=sys.float_info.epsilon #机器可以区分出的两个浮点数的最小区别 
fs=16 #font size 1
fs_2=16 #font size 2
lw=4 #linewidth for visualization
thresh=2 #threshold for dynamic measures (i.e., there needs to be at least two points for each observation)

# %%
#提取每条rumour的cascade数量
veracity2rid2count=defaultdict(lambda: defaultdict(int))
for cascade,metadata in cascade_id2metadata.items():
    veracity=metadata['veracity']
    rid=metadata['rumor_id']
    veracity2rid2count[veracity][rid]+=1

# %%
plt.figure(figsize = [5,5])
#每条rumour的cascade数量以及对应的所占rumour总数的百分比（cumulative）

for veracity,rid2count in veracity2rid2count.items():
    rid_count=list(rid2count.items()) #包含tuple的list
    rid_count.sort(key=lambda x:x[1], reverse=True) #用每个rid的count作为排序依据，倒排
    y=[count for rid,count in rid_count]
    total=float(len(rid_count))
    xf=[]
    pf=[]
    y.sort()
    counts=list(set(y))
    counts.sort()
    for d in counts:
        ind=y.index(d)
        count=len(y[ind:])
        p=(count/float(total)) * 100
        xf.append(d)
        pf.append(p)
    plt.plot(xf,pf,'-',color=veracity2color[veracity],linewidth=lw, label = veracity)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Number of Cascades",fontsize=16)
plt.ylabel("CCDF (% Rumors)",fontsize=16)
plt.xticks(rotation='horizontal')
plt.legend()
plt.show()

# %% [markdown]
# ## 任务4. Figure 1D
#
# 改写以上Figure 1B的代码绘制Figrue 1D

# %%
#提取politics rumour的cascade数量
#其实这道题和Fig1C几乎一样，只是需要提取politics数据
veracity2rid2count=defaultdict(lambda: defaultdict(int))
for cascade,metadata in cascade_id2metadata.items():
    veracity=metadata['veracity']
    rid=metadata['rumor_id']
    category=metadata['rumor_category']
    if category!='Politics':
        continue
    veracity2rid2count[veracity][rid]+=1

# %%
# 绘图
plt.figure(figsize = [5,5])

for veracity,rid2count in veracity2rid2count.items():
    rid_count=list(rid2count.items())
    rid_count.sort(key=lambda x:x[1], reverse=True)
    y=[count for rid,count in rid_count]
    total=float(len(rid_count))
    xf=[]
    pf=[]
    y.sort()
    counts=list(set(y))
    counts.sort()
    for d in counts:
        ind=y.index(d)
        count=len(y[ind:])
        p=(count/float(total)) * 100
        xf.append(d)
        pf.append(p)
    plt.plot(xf,pf,'-',color=veracity2color[veracity],linewidth=lw, label=veracity)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Number of Political Cascades",fontsize=16)
plt.ylabel("CCDF (% Rumors)",fontsize=16)
plt.xticks(rotation='horizontal')
plt.legend()
plt.show()

# %% [markdown]
# ## Figrue 1C

# %%
'''The total number of false rumors peaked at the end of both 2013 and 2015 and again at the
end of 2016, corresponding to the last U.S. presi- dential election (Fig. 1C)'''

import datetime

# 将时间分块为季度
def quarter_year(date):
    if date.month<4:
        daty='01'
    elif date.month<7:
        daty='04'
    elif date.month<10:
        daty='07'
    else:
        daty='10'
    date=str(date.year)+'-'+daty+'-'+'01'
    date = parser.parse(date)
    return date

import dateutil.parser as parser

#每个季度cascade数量统计
veracity2date2count=defaultdict(lambda: defaultdict(int))
for cascade,metadata in cascade_id2metadata.items():
    veracity=metadata['veracity']
    y,m,d = metadata['start_date'][:3]
    date=datetime.date(y,m,d)
    date = quarter_year(date)
    veracity2date2count[veracity][date]+=1

# %%
veracity2date2count
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'FALSE': defaultdict(int,
#                          {datetime.datetime(2013, 7, 1, 0, 0): 3109,
#                           datetime.datetime(2013, 4, 1, 0, 0): 3090,
#                           datetime.datetime(2015, 4, 1, 0, 0): 2618,
#                           datetime.datetime(2013, 10, 1, 0, 0): 10329,
#                           datetime.datetime(2016, 1, 1, 0, 0): 7526,
#                           datetime.datetime(2016, 7, 1, 0, 0): 10296,
#                           datetime.datetime(2016, 4, 1, 0, 0): 3403,
#                           datetime.datetime(2012, 10, 1, 0, 0): 2448,
#                           datetime.datetime(2016, 10, 1, 0, 0): 1675,
#                           datetime.datetime(2015, 10, 1, 0, 0): 7984,
#                           datetime.datetime(2015, 7, 1, 0, 0): 3175,
#                           datetime.datetime(2014, 7, 1, 0, 0): 2967,
#                           datetime.datetime(2014, 10, 1, 0, 0): 4336,
#                           datetime.datetime(2012, 4, 1, 0, 0): 598,
#                           datetime.datetime(2012, 7, 1, 0, 0): 3411,
#                           datetime.datetime(2013, 1, 1, 0, 0): 2948,
#                           datetime.datetime(2014, 4, 1, 0, 0): 4263,
#                           datetime.datetime(2012, 1, 1, 0, 0): 593,
#                           datetime.datetime(2011, 4, 1, 0, 0): 151,
#                           datetime.datetime(2015, 1, 1, 0, 0): 2193,
#                           datetime.datetime(2014, 1, 1, 0, 0): 4533,
#                           datetime.datetime(2011, 7, 1, 0, 0): 51,
#                           datetime.datetime(2009, 4, 1, 0, 0): 3,
#                           datetime.datetime(2011, 10, 1, 0, 0): 615,
#                           datetime.datetime(2010, 10, 1, 0, 0): 35,
#                           datetime.datetime(2010, 1, 1, 0, 0): 9,
#                           datetime.datetime(2009, 10, 1, 0, 0): 13,
#                           datetime.datetime(2011, 1, 1, 0, 0): 198,
#                           datetime.datetime(2010, 4, 1, 0, 0): 16,
#                           datetime.datetime(2009, 7, 1, 0, 0): 1,
#                           datetime.datetime(2008, 10, 1, 0, 0): 1,
#                           datetime.datetime(2010, 7, 1, 0, 0): 17}),
#              'TRUE': defaultdict(int,
#                          {datetime.datetime(2014, 4, 1, 0, 0): 1734,
#                           datetime.datetime(2013, 4, 1, 0, 0): 3283,
#                           datetime.datetime(2014, 1, 1, 0, 0): 7032,
#                           datetime.datetime(2015, 7, 1, 0, 0): 206,
#                           datetime.datetime(2016, 1, 1, 0, 0): 8335,
#                           datetime.datetime(2014, 10, 1, 0, 0): 330,
#                           datetime.datetime(2016, 7, 1, 0, 0): 612,
#                           datetime.datetime(2016, 4, 1, 0, 0): 1358,
#                           datetime.datetime(2011, 10, 1, 0, 0): 47,
#                           datetime.datetime(2016, 10, 1, 0, 0): 226,
#                           datetime.datetime(2014, 7, 1, 0, 0): 258,
#                           datetime.datetime(2015, 4, 1, 0, 0): 192,
#                           datetime.datetime(2015, 10, 1, 0, 0): 231,
#                           datetime.datetime(2015, 1, 1, 0, 0): 284,
#                           datetime.datetime(2013, 1, 1, 0, 0): 32,
#                           datetime.datetime(2012, 4, 1, 0, 0): 19,
#                           datetime.datetime(2013, 10, 1, 0, 0): 69,
#                           datetime.datetime(2012, 10, 1, 0, 0): 30,
#                           datetime.datetime(2012, 7, 1, 0, 0): 43,
#                           datetime.datetime(2012, 1, 1, 0, 0): 12,
#                           datetime.datetime(2013, 7, 1, 0, 0): 51,
#                           datetime.datetime(2011, 4, 1, 0, 0): 4,
#                           datetime.datetime(2011, 1, 1, 0, 0): 4,
#                           datetime.datetime(2011, 7, 1, 0, 0): 11,
#                           datetime.datetime(2010, 4, 1, 0, 0): 2,
#                           datetime.datetime(2010, 10, 1, 0, 0): 3,
#                           datetime.datetime(2009, 10, 1, 0, 0): 1}),
#              'MIXED': defaultdict(int,
#                          {datetime.datetime(2014, 10, 1, 0, 0): 1651,
#                           datetime.datetime(2014, 1, 1, 0, 0): 198,
#                           datetime.datetime(2015, 10, 1, 0, 0): 430,
#                           datetime.datetime(2015, 1, 1, 0, 0): 1998,
#                           datetime.datetime(2013, 7, 1, 0, 0): 1029,
#                           datetime.datetime(2015, 7, 1, 0, 0): 1263,
#                           datetime.datetime(2016, 1, 1, 0, 0): 721,
#                           datetime.datetime(2014, 7, 1, 0, 0): 1063,
#                           datetime.datetime(2014, 4, 1, 0, 0): 4419,
#                           datetime.datetime(2016, 7, 1, 0, 0): 181,
#                           datetime.datetime(2012, 7, 1, 0, 0): 67,
#                           datetime.datetime(2013, 10, 1, 0, 0): 1814,
#                           datetime.datetime(2016, 4, 1, 0, 0): 361,
#                           datetime.datetime(2015, 4, 1, 0, 0): 1289,
#                           datetime.datetime(2013, 1, 1, 0, 0): 837,
#                           datetime.datetime(2013, 4, 1, 0, 0): 265,
#                           datetime.datetime(2012, 1, 1, 0, 0): 1287,
#                           datetime.datetime(2011, 4, 1, 0, 0): 9,
#                           datetime.datetime(2011, 10, 1, 0, 0): 56,
#                           datetime.datetime(2012, 10, 1, 0, 0): 44,
#                           datetime.datetime(2011, 7, 1, 0, 0): 11,
#                           datetime.datetime(2012, 4, 1, 0, 0): 168,
#                           datetime.datetime(2010, 10, 1, 0, 0): 8,
#                           datetime.datetime(2016, 10, 1, 0, 0): 111,
#                           datetime.datetime(2011, 1, 1, 0, 0): 2,
#                           datetime.datetime(2010, 7, 1, 0, 0): 2,
#                           datetime.datetime(2009, 4, 1, 0, 0): 1,
#                           datetime.datetime(2009, 1, 1, 0, 0): 1,
#                           datetime.datetime(2008, 10, 1, 0, 0): 1})})

# %%
#画图

for veracity,date2count in veracity2date2count.items():
    date_count=list(date2count.items())
    date_count.sort(key=lambda x:x[0])
    x=[d for d,c in date_count if (d.year!=2016 or d.month<10)]
    y=[c for d,c in date_count if (d.year!=2016 or d.month<10)]
    plt.plot(x,y,color=veracity2color[veracity],linewidth=lw)
plt.xlabel('Year',fontsize=16)
plt.ylabel("Count (All Cascades)",fontsize=16)
plt.show()

# %% [markdown]
# ## 任务5. Figrue 1E
#
# 改写以上Figure 1B的代码绘制Figrue 1D

# %%
veracity2date2count=defaultdict(lambda: defaultdict(int))
for cascade,metadata in cascade_id2metadata.items():
    veracity=metadata['veracity']
    category=metadata['rumor_category']
    if category!='Politics':
        continue
    y,m,d = metadata['start_date'][:3]
    date=datetime.date(y,m,d)
    date = quarter_year(date)
    veracity2date2count[veracity][date]+=1

# %%
# 绘图
for veracity,date2count in veracity2date2count.items():
    date_count=list(date2count.items())
    date_count.sort(key=lambda x:x[0])
    x=[d for d,c in date_count if (d.year!=2016 or d.month<10)]
    y=[c for d,c in date_count if (d.year!=2016 or d.month<10)]
    plt.plot(x,y,color=veracity2color[veracity],linewidth=lw, label = veracity)
plt.xlabel('Year',fontsize=16)
plt.ylabel("Count (Political Cascades)",fontsize=16)
plt.legend()
plt.show()

# %% [markdown]
# ## Figrue 1F

# %%
#每个类别谣言的直方图

def kit(x, pos):
    val_str = '{:g}'.format(x)
    if val_str=='5000':
        return '5K'
    elif val_str=='15000':
        return '15K'
    elif val_str=='25000':
        return '25K'
    elif val_str=='35000':
        return '35K'
    elif val_str=='45000':
        return '45K'
    elif val_str=='10000':
        return '10K'
    elif val_str=='20000':
        return '20K'
    elif val_str=='30000':
        return '30K'
    elif val_str=='40000':
        return '40K'
    elif val_str=='50000':
        return '50K'
    elif val_str=='60000':
        return '60K'
    elif val_str=='100000':
        return '100K'
    else:
        return val_str

# %%
category2count=defaultdict(int)
for cascade,metadata in cascade_id2metadata.items():
    category=metadata['rumor_category']
    category2count[category]+=1
cat_count=list(category2count.items())
cat_count.sort(key=lambda x:x[1], reverse=True)
y=[count for cat,count in cat_count]
x=['Politics','Urban Legends','Business','Terrorism & War',
   'Science & Technology','Entertainment','Natural Disasters']
x.reverse()
y.reverse()
width = 0.015
pos=[ 0.17 , 0.19 , 0.21 , 0.23 , 0.25 , 0.27 , 0.29]
ax = plt.subplot(111)
formatter = plt.FuncFormatter(kit)
ax.xaxis.set_major_formatter(formatter)
ax.barh(pos,y,width, align='center',color ='#486E7F' )
plt.yticks(pos, x,fontsize=fs)
plt.ylim([0.155,0.305])
ax.tick_params(axis='both', which='major', labelsize=16)
plt.xlabel("Number of Cascades",fontsize=16)
plt.xticks(rotation='horizontal')
ax.set_xticks([0, 10000, 20000,30000,40000,50000])
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Figrue 2A

# %%
def calc_robust_sem(y_r,clusters):
    '''
    calculated the cluster robust semof array
    '''
    x_r=[1]*len(y_r)
    res = sm.OLS(y_r,x_r).fit(cov_type='cluster',cov_kwds={'groups': clusters})
    robust_sem=res.bse[0]
    return robust_sem

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats
from scipy.spatial.distance import cosine

veracity2depths=defaultdict(list)
veracity2clusters=defaultdict(list)
for cascade,metadata in cascade_id2metadata.items():
    veracity=metadata['veracity']
    rid=metadata['rumor_id']
    depth=metadata['depth']+1 #adding one for smoothing purposes
    veracity2depths[veracity].append(depth)
    veracity2clusters[veracity].append(rid)
    
print ('##############################')
print ('Depth Stats. FALSE/TRUE/MIXED')
print ('Mean (log)',np.mean(np.log10(veracity2depths['FALSE'])),
       np.mean(np.log10(veracity2depths['TRUE'])),
       np.mean(np.log10(veracity2depths['MIXED'])) )
print ('Robust SEM (log)',calc_robust_sem(np.log10(veracity2depths['FALSE']),veracity2clusters['FALSE']),\
    calc_robust_sem(np.log10(veracity2depths['TRUE']),veracity2clusters['TRUE']),\
    calc_robust_sem(np.log10(veracity2depths['MIXED']),veracity2clusters['MIXED']) )
print  ("KS test (false and true):",stats.ks_2samp(veracity2depths['FALSE'],veracity2depths['TRUE']))

# %%
'''
FIGURE 2A
CCDF of depth for all rumors
'''
ax = plt.subplot(111)
ax.set_xscale('log')
ax.set_yscale('log')

for veracity,depths in veracity2depths.items():
    if veracity=='MIXED':
        continue
    total=float(len(depths))
    xf=[]
    pf=[]
    depths.sort()
    counts=list(set(depths))
    counts.sort()
    for d in counts:
        ind=depths.index(d)
        count=len(depths[ind:])
        p=(count/float(total)) * 100
        xf.append(d)
        pf.append(p)
    ax.plot(xf,pf,color=veracity2color[veracity],linewidth=lw, label=veracity)
    
plt.xlabel("Cascade Depth",fontsize=16)
plt.ylabel("CCDF (%)",fontsize=16)
ax.tick_params(axis='both', which='major')
plt.xticks(rotation='horizontal')
plt.legend()
plt.show()

# %% [markdown]
# ## 任务6： Figrue 2B
#
# 改写以上Figure 1B的代码绘制Figrue 1D

# %%
# compute veracity2sizes
veracity2sizes=
    
print ('##############################')
print ('Size Stats. FALSE/TRUE/MIXED')
print ('Mean (log)',np.mean(np.log10(veracity2sizes['FALSE'])),
np.mean(np.log10(veracity2sizes['TRUE'])),np.mean(np.log10(veracity2sizes['MIXED'])))
print ('Robust SEM (log)',calc_robust_sem(np.log10(veracity2sizes['FALSE']),veracity2clusters['FALSE']),\
    calc_robust_sem(np.log10(veracity2sizes['TRUE']),veracity2clusters['TRUE']),\
    calc_robust_sem(np.log10(veracity2sizes['MIXED']),veracity2clusters['MIXED']))
print  ("KS test (false and true):",stats.ks_2samp(veracity2sizes['FALSE'],
                                                  veracity2sizes['TRUE']))

# %%
'''
FIGURE 2B
CCDF of size for all rumors
'''

# %% [markdown]
# 以上任务1到任务6是必须完成的任务，可以参考作者给出的代码。
#
# - 选做（非必选）绘制 Figure 2C-H
#
# - 作业2（选做，非必选）. Henry Farber's (2015) study of the behavior of New York City taxi drivers
#  https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#
# # This is the end!
