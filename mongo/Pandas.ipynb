# %% [markdown]
# ### Pandas read InstaDB try

# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_csv('/Users/stevenchen/Documents/workspace/dataset/test.csv') 
#df1 = df.head(100000)
#df1 = df.drop(columns = "isBot", axis = 1, inplace = False)

# %%
# df1.drop(columns='age', inplace = True)
# df1.drop(columns='interactionRate', inplace = True)
# df1.drop(columns='isBot',inplace = True)
# df1.dropna(inplace=True)

# %%
# import matplotlib.pyplot as plt 
# df2 = df1.head(5)
# #df2['followerCount'] = df2['followerCount'].astype(float)
# #df2['followingCount'] = df2['followingCount'].astype(float)

# df1 = df1[df['followerCount']<5000]
# df1 = df1[df['followingCount']<5000]
# df1.plot.scatter(x='followingCount', y='followerCount',figsize = (50,40))
