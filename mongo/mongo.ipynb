# %% [markdown]
# ## MongoDB pymongo

# %%
# Mongo authentication Ex

from pymongo import MongoClient 
import urllib.parse
import pprint


username = urllib.parse.quote_plus('metaplugRead')
password = urllib.parse.quote_plus('metaplugRead!@#')
host = "13.52.82.150"
port = 27017

client = MongoClient('mongodb://%s:%s@13.52.82.150:27017' % (username, password)+'/?authSource=InstaDB')
# 我草你妈的终于搞定了.
print(client.InstaDB['accounts'].find_one())

#mongo 13.52.82.150:27017/InstaDB -u 'metaplugRead' -p 'metaplugRead!@#'
#mongoexport --username 'metaplugRead' --password 'metaplugRead!@#' --host 13.52.82.150 --db InstaDB --collection accounts --type=csv --fields='id,followerCount,isBusiness,followingCount,isBot' -o test.csv


client_temp = MongoClient('mongodb://localhost:27017/') 
# 我叼你妈的个嗨 搞了半天 
# mongo连不上, start mongodb找不到, 结果用的是mongodb-community  
# 要brew services start mangodb-community
# db = client_temp.test_database
# print(db.list_collection_names())
print("config done")
# Out:
# {'_id': ObjectId('5c5013301ae1e130a4637cf7'), 'id': 186790618, '__v': 0, 'biography': 'Made In Argentina, raised in WPB, FL, taking over NYC.\nBorn in the wrong decade. \nDreamer.\nPolaroid collection : @artofpolaroid', 'createdAt': datetime.datetime(2019, 1, 29, 8, 47, 44, 599000), 'followerCount': 1026, 'isBusiness': False, 'isPrivate': False, 'isVerified': False, 'scannedAccountsFollowing': [1931295368, 0, 7416701380.0], 'updatedAt': datetime.datetime(2019, 8, 13, 2, 27, 9, 174000), 'username': 'lifeofagu', 'analytics': {'language': ['en'], 'interactionRate': 0.07251461988304093, 'location': {'name': 'SoHo, Manhattan', 'point': {'type': 'Point', 'coordinates': [-74.000833, 40.723056]}}, 'words': ['35mm', 'made', 'argentina', 'raised', 'wpb', 'taking', 'nyc', 'born', 'wrong', 'decade'], 'influence': 0, 'ratio': 0.8724489795918368, 'isBot': False, 'age': 28, 'education': 'University Student', 'version': '1.1.0'}, 'following': [46407054, 8007894210.0, 17575251, 3623781319.0, 3537905466.0, 678337225, 3084071455.0, 589892718, 8989634, 34930659, 262574392, 337709684, 10569898660.0, 308236480, 21098862, 3661179124.0, 1537966913, 8629016679.0, 5338683837.0, 3187232278.0, 1603501617, 484999375, 4831422090.0, 3965084820.0, 2311145, 19055834, 579391430, 213218680, 39105915, 4329876451.0, 32947920, 3883998367.0, 2015314832, 3963561474.0, 8070660870.0, 3573092288.0, 21334378, 8251375780.0, 18427291, 1476342094, 35232494, 15953133, 34025625, 3440189, 7325202364.0, 8668359, 5363097852.0, 25627123, 42852407, 8995479, 5310969720.0, 4582056719.0, 2022586880, 7011648611.0, 464809666, 199748660, 3548946731